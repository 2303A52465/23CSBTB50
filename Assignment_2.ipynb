# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52465/23CSBTB50/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy import stats as s

# %%
d=pd.read_excel('/AI LAB-2.xlsx')
d
# Out:
#      SID      S.Name  Age Course  Contact No.
# 0   2111       Arnav   19    CSE   9392646488
# 1   2112     Vineeth   19   AIML   9845845845
# 2   2113       Pawan   19    CSE   9595488675
# 3   2114      Vishwa   19   AIML   6151865458
# 4   2115  Chaithanya   19   AIML   8589265467
# 5   2116      Charan   19   AIML   9948315428
# 6   2117      Rohith   19   AIML   9961543129
# 7   2118     Goutham   19    CSE   6281854879
# 8   2119    Praneeth   19    CSE   6484982755
# 9   2120     Manmith   19    CSE   6585798684
# 10  2121       Nipun   19   AIML   6284967135
# 11  2122      Sujith   19    CSE   8683452565
# 12  2123       Sayam   19   AIML   9595454565
# 13  2124        Mani   19    CSE   6483948465
# 14  2125       Akhil   19    CSC   6235854796
# 15  2126     Dhanush   19    CSC   8683652471
# 16  2127    Shashank   19   AIML   9285416489
# 17  2128       Suraj   19    CSC   8461248679
# 18  2129     Abhinay   19    CSC   6487231456
# ...

# %%
a=pd.read_csv("/content/heart.csv")
a
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
b=pd.read_csv("/content/games_dataset.csv")
b
# Out:
#                                     Game Name       Genre         Platform  \
# 0                   Sekiro: Shadows Die Twice      Sports  Nintendo Switch
# 1                                     Control      Puzzle  Nintendo Switch
# 2                                    Among Us    Strategy  Nintendo Switch
# 3                Call of Duty: Modern Warfare     Stealth      PlayStation
# 4                           League of Legends  Simulation               PC
# ...                                       ...         ...              ...
# 4995  The Legend of Zelda: Breath of the Wild      Sports               PC
# 4996                Assassin's Creed Valhalla     Stealth           Mobile
# 4997             Fall Guys: Ultimate Knockout      Sports           Mobile
# 4998                            Borderlands 3  Platformer             Xbox
# 4999         Counter-Strike: Global Offensive      Action      PlayStation
#
#       Release Year  User Rating
# 0             2014     9.654719
# ...
